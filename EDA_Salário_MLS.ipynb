# %% [markdown]
# <a href="https://colab.research.google.com/github/luanrossini/estudo_gols_yuri_alberto/blob/main/EDA_Sal%C3%A1rio_MLS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introdução
#
# Este notebook tem como objetivo realizar uma Análise exploratória de dados (EDA) em um conjunto de dados disponivel no Kaggle sobre os salarios dos jogadores da Major League Soccer (MLS) entre os anos de 2007 a 2017.
#
# O objetivo desta EDA é proporcionar uma compreensão mais aprofundada da estrutura de remuneração dos jogadores da liga americana de futebol, podendo revelar insights valiosos sobre a distribuição, tendências e características dos salários dos jogadores na liga.

# %% [markdown]
# ## Dicionário de Dados
#
# club: Abreviação do nome do time </br>
# last_name: Último nome do jogador </br>
# last_name: Último nome do jogador </br>
# first_name: Primeiro nome do jogador </br>
# last_name: Último nome do jogador </br>
# position: Posição abreviada do jogador</br>
# last_name: Último nome do jogador </br>
# base_salary: Base salarial</br>
# last_name: Último nome do jogador </br>
# guaranteed_compensation: Compensação salarial</br>

# %%
# Importando as bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt
import os

# %%
# Carregar cada base de dados em DataFrames separados
df_2007 = pd.read_csv('mls-salaries-2007.csv')
df_2008 = pd.read_csv('mls-salaries-2008.csv')
df_2009 = pd.read_csv('mls-salaries-2009.csv')
df_2010 = pd.read_csv('mls-salaries-2010.csv')
df_2011 = pd.read_csv('mls-salaries-2011.csv')
df_2012 = pd.read_csv('mls-salaries-2012.csv')
df_2013 = pd.read_csv('mls-salaries-2013.csv')
df_2014 = pd.read_csv('mls-salaries-2014.csv')
df_2015 = pd.read_csv('mls-salaries-2015.csv')
df_2016 = pd.read_csv('mls-salaries-2016.csv')
df_2017 = pd.read_csv('mls-salaries-2017.csv')

# Adicionar uma coluna 'Season' em cada DataFrame correspondente à temporada da MLS
df_2007['Season'] = 2007
df_2008['Season'] = 2008
df_2009['Season'] = 2009
df_2010['Season'] = 2010
df_2011['Season'] = 2011
df_2012['Season'] = 2012
df_2013['Season'] = 2013
df_2014['Season'] = 2014
df_2015['Season'] = 2015
df_2016['Season'] = 2016
df_2017['Season'] = 2017

# Concatenar todos os dados em um único DataFrame
df = pd.concat([df_2007, df_2008, df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017])

# %%
# Olhando as 5 primeiras linhas do dataset
df.head()
# Out:
#   club last_name  first_name position  base_salary  guaranteed_compensation  \
# 0  CHI     Armas       Chris        M     225000.0                 225000.0
# 1  CHI    Banner     Michael        M      12900.0                  12900.0
# 2  CHI   Barrett        Chad        F      41212.5                  48712.5
# 3  CHI    Blanco  Cuauhtemoc        F    2492316.0                2666778.0
# 4  CHI     Brown        C.J.        D     106391.0                 106391.0
#
#    Season
# 0    2007
# 1    2007
# 2    2007
# 3    2007
# 4    2007

# %%
# Tamanho da base de dados

df.shape
# Out:
# (5553, 7)

# %%
# Explorando as colunas do dataset

df.columns
# Out:
# Index(['club', 'last_name', 'first_name', 'position', 'base_salary',
#        'guaranteed_compensation', 'Season'],
#       dtype='object')

# %% [markdown]
# ## Limpeza e tratamento dos dados

# %%
# Explorando valores nulos ou ausentes no dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5553 entries, 0 to 615
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   club                     5533 non-null   object
#  1   last_name                5553 non-null   object
#  2   first_name               5534 non-null   object
#  3   position                 5552 non-null   object
#  4   base_salary              5552 non-null   float64
#  5   guaranteed_compensation  5552 non-null   float64
#  6   Season                   5553 non-null   int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 347.1+ KB

# %%
# Dados duplicados?

df.duplicated().sum()
# Out:
# 0

# %%
null_data = df[df.isnull().any(axis=1)]
null_data
# Out:
#       club   last_name    first_name position  base_salary  \
# 188    SEA      Keller         Kasey       GK          NaN
# 236     KC    Jeferson           NaN        F    429996.00
# 6      CHI        Alex           NaN        M     96000.00
# 250     LA     Juninho           NaN        M     50000.00
# 442    NaN     Sassano          Luke      M-D     81000.00
# 534    NaN       White      Jeremiah        M     44004.00
# 9      CHI        Alex           NaN        M    110000.00
# 23     NaN  Araujo Jr.         Paulo        F     60000.00
# 151    NaN    Dunfield         Terry        M    120000.00
# 268     LA     Juninho           NaN        M    290000.00
# 364    NaN       Muniz          Nico        M     46500.00
# 7      CHI        Alex           NaN        M    123750.00
# 66     NaN       Borja        Carlos        D     52313.00
# 160    PHI     Fabinho           NaN        D     96000.00
# 192    NaN     Gardner        Joshua        M     70000.00
# 263     LA     Juninho           NaN        M    325000.00
# 268    ORL        Kaka           NaN        M   6660000.00
# 340    NaN       Melia           Tim       GK     70000.00
# 11     HOU        Alex           NaN        M    142000.00
# 130    NaN        Dike        Bright        F     60638.00
# 234    NaN     Hurtado  Jhon Kennedy        D    230000.00
# 255     LA     Juninho           NaN        M    350000.00
# 258    ORL        Kaka           NaN        M   6660000.00
# 297    NaN    Lochhead          Tony        D    134375.00
# 396    RSL       Pecka           NaN        M     60000.00
# 485     SJ       Silva       Matheus      NaN     50000.04
# 525    NaN      Tshuma       Schillo        F     85000.00
# 340    ORL        Kaka           NaN        M   6660000.00
# 367    PHI     Ilsinho           NaN        M    430000.00
# 549    NaN      Gargan           Dan        D    145000.00
# 550    NaN    Martinez      Cristian        M     62508.00
# 551    NaN       Moore          Luke        F    115000.00
# 552    NaN      Nyassi         Sanna        M    135000.00
# 553    NaN      Ovalle        Adolfo        M     63000.00
# 554    NaN      Tshuma       Schillo        F     81999.96
# 46     CHI     Juninho           NaN        M    700008.00
# 265  MNUFC       Ibson           NaN        M    200004.00
# 401    ORL        Kaka           NaN        M   6660000.00
# 429    PHI     Ilsinho           NaN        M    470000.00
# 614    NaN     Babouli            Mo        F     54075.00
# 615    NaN      Ramajo  David Mateos        D    420000.00
#
#      guaranteed_compensation  Season
# 188                      NaN    2008
# 236                484996.00    2011
# 6                  105950.00    2012
# 250                 65625.00    2012
# 442                 83025.00    2012
# 534                 44004.00    2012
# 9                  119950.00    2013
# 23                  60000.00    2013
# 151                120000.00    2013
# 268                290000.00    2013
# 364                 48500.00    2013
# 7                  133700.00    2014
# 66                  52313.00    2014
# 160                100500.00    2014
# 192                 70000.00    2014
# 263                325000.00    2014
# 268               7167500.00    2014
# 340                 75000.00    2014
# 11                 142000.00    2015
# 130                 64388.00    2015
# 234                230000.00    2015
# 255                350000.00    2015
# 258               7167500.00    2015
# 297                134375.00    2015
# 396                 64166.67    2015
# 485                 50000.04    2015
# 525                123000.00    2015
# 340               7167500.00    2016
# 367                478333.33    2016
# 549                145000.00    2016
# 550                 67008.00    2016
# 551                137500.00    2016
# 552                141250.00    2016
# 553                 73500.00    2016
# 554                119999.96    2016
# 46                 716674.67    2017
# 265                210337.40    2017
# 401               7167500.00    2017
# 429                518333.33    2017
# 614                 54075.00    2017
# 615                453333.33    2017

# %%
# Criando a coluna "Name" com a junção do primeiro e último nome
def fullname(x, y):
    if str(x) == "nan":
        return str(y)
    else:
        return str(x) + " " + str(y)

# Aplicando o nome no dataset
df['Name'] = np.vectorize(fullname)(df['first_name'], df['last_name'])
df.head()
# Out:
#   club last_name  first_name position  base_salary  guaranteed_compensation  \
# 0  CHI     Armas       Chris        M     225000.0                 225000.0
# 1  CHI    Banner     Michael        M      12900.0                  12900.0
# 2  CHI   Barrett        Chad        F      41212.5                  48712.5
# 3  CHI    Blanco  Cuauhtemoc        F    2492316.0                2666778.0
# 4  CHI     Brown        C.J.        D     106391.0                 106391.0
#
#    Season               Name
# 0    2007        Chris Armas
# 1    2007     Michael Banner
# 2    2007       Chad Barrett
# 3    2007  Cuauhtemoc Blanco
# 4    2007         C.J. Brown

# %%
# Removendo as colunas 'last_name' e 'first_name'
df = df.drop(['last_name', 'first_name'], axis = 1)

# %%
# Ordenação das colunas do dataframe
df = df[['Season', 'club', 'Name', 'position', 'guaranteed_compensation', 'base_salary']]
df.head()
# Out:
#    Season club               Name position  guaranteed_compensation  \
# 0    2007  CHI        Chris Armas        M                 225000.0
# 1    2007  CHI     Michael Banner        M                  12900.0
# 2    2007  CHI       Chad Barrett        F                  48712.5
# 3    2007  CHI  Cuauhtemoc Blanco        F                2666778.0
# 4    2007  CHI         C.J. Brown        D                 106391.0
#
#    base_salary
# 0     225000.0
# 1      12900.0
# 2      41212.5
# 3    2492316.0
# 4     106391.0

# %%
# Alterar a variável "club" de Pool, POOL ou nula para "Free Agent"
def free_agent(x):
    if str(x) == "nan":
        return str("Free Agent")
    elif str(x) == 'None':
        return str("Free Agent")
    elif str(x) == 'Pool':
        return str("Free Agent")
    elif str(x) == 'POOL':
        return str("Free Agent")
    else:
        return str(x)

# Aplicando a função free_agent na coluna "club"
df['club'] = df['club'].apply(free_agent)

# %%
df
# Out:
#      Season        club                 Name position  \
# 0      2007         CHI          Chris Armas        M
# 1      2007         CHI       Michael Banner        M
# 2      2007         CHI         Chad Barrett        F
# 3      2007         CHI    Cuauhtemoc Blanco        F
# 4      2007         CHI           C.J. Brown        D
# ..      ...         ...                  ...      ...
# 611    2017         VAN       Paolo Tornaghi       GK
# 612    2017         VAN       Kendall Waston        D
# 613    2017         VAN     Sheanon Williams        D
# 614    2017  Free Agent           Mo Babouli        F
# 615    2017  Free Agent  David Mateos Ramajo        D
#
#      guaranteed_compensation  base_salary
# 0                  225000.00     225000.0
# 1                   12900.00      12900.0
# 2                   48712.50      41212.5
# 3                 2666778.00    2492316.0
# 4                  106391.00     106391.0
# ..                       ...          ...
# 611                 80000.00      80000.0
# 612                368125.00     350000.0
# 613                184000.00     175000.0
# 614                 54075.00      54075.0
# 615                453333.33     420000.0
#
# [5553 rows x 6 columns]

# %%
# Comportamento das variáveis não numéricas

df.describe(exclude = np.number)
# Out:
#         club         Name position
# count   5553         5553     5552
# unique    27         2005       16
# top      DAL  Chris Seitz        M
# freq     322           11     1829

# %%
# Definindo a posição dos jogadores para 3 tipos: Ataque, Defesa e Meio-campo
def new_position(x):
    if x in ['M', 'MF', 'M/F', 'M-D', 'M-F', 'F-M', 'F/M', 'D-M']:
        return 'Meio-campo'
    elif x in ['F', 'F-D', 'D/F']:
        return 'Ataque'
    elif x in ['D', 'GK', 'D-F', 'M-D', 'D/M']:
        return 'Defesa'
    else:
        return 'Outro'

# Aplicar a função mapear_posicao para criar a nova classificação
df['new_position'] = df['position'].apply(new_position)
df
# Out:
#      Season        club                 Name position  \
# 0      2007         CHI          Chris Armas        M
# 1      2007         CHI       Michael Banner        M
# 2      2007         CHI         Chad Barrett        F
# 3      2007         CHI    Cuauhtemoc Blanco        F
# 4      2007         CHI           C.J. Brown        D
# ..      ...         ...                  ...      ...
# 611    2017         VAN       Paolo Tornaghi       GK
# 612    2017         VAN       Kendall Waston        D
# 613    2017         VAN     Sheanon Williams        D
# 614    2017  Free Agent           Mo Babouli        F
# 615    2017  Free Agent  David Mateos Ramajo        D
#
#      guaranteed_compensation  base_salary new_position
# 0                  225000.00     225000.0   Meio-campo
# 1                   12900.00      12900.0   Meio-campo
# 2                   48712.50      41212.5       Ataque
# 3                 2666778.00    2492316.0       Ataque
# 4                  106391.00     106391.0       Defesa
# ..                       ...          ...          ...
# 611                 80000.00      80000.0       Defesa
# 612                368125.00     350000.0       Defesa
# 613                184000.00     175000.0       Defesa
# 614                 54075.00      54075.0       Ataque
# 615                453333.33     420000.0       Defesa
#
# [5553 rows x 7 columns]

# %%
# Função para trocar as abreviações para os nomes completos dos clubes pelo nome completo
def nome_completo_clube(club):
    clubes = {
        'CHI': 'Chicago Fire FC',
        'CHV': 'Chivas USA',
        'CLB': 'Columbus Crew SC',
        'COL': 'Colorado Rapids',
        'DAL': 'FC Dallas',
        'DC': 'D.C. United',
        'HOU': 'Houston Dynamo FC',
        'KC': 'Sporting Kansas City',
        'LA': 'LA Galaxy',
        'NE': 'New England Revolution',
        'NY': 'New York Red Bulls',
        'Free Agent': 'Free Agent',
        'RSL': 'Real Salt Lake',
        'TFC': 'Toronto FC',
        'SJ': 'San Jose Earthquakes',
        'SEA': 'Seattle Sounders FC',
        'PHI': 'Philadelphia Union',
        'VAN': 'Vancouver Whitecaps FC',
        'POR': 'Portland Timbers',
        'TOR': 'Toronto FC',
        'MTL': 'Montreal Impact',
        'ORL': 'Orlando City SC',
        'NYCFC': 'New York City FC',
        'ATL': 'Atlanta United FC',
        'NYRB': 'New York Red Bulls',
        'LAFC': 'Los Angeles Football Club',
        'MNUFC': 'Minnesota United FC'
    }
    return clubes.get(club, 'Desconhecido')

# Aplicar a função ao DataFrame para converter as abreviações de clube para os nomes completos
df['club_new'] = df['club'].apply(nome_completo_clube)
df
# Out:
#      Season        club                 Name position  \
# 0      2007         CHI          Chris Armas        M
# 1      2007         CHI       Michael Banner        M
# 2      2007         CHI         Chad Barrett        F
# 3      2007         CHI    Cuauhtemoc Blanco        F
# 4      2007         CHI           C.J. Brown        D
# ..      ...         ...                  ...      ...
# 611    2017         VAN       Paolo Tornaghi       GK
# 612    2017         VAN       Kendall Waston        D
# 613    2017         VAN     Sheanon Williams        D
# 614    2017  Free Agent           Mo Babouli        F
# 615    2017  Free Agent  David Mateos Ramajo        D
#
#      guaranteed_compensation  base_salary new_position                club_new
# 0                  225000.00     225000.0   Meio-campo         Chicago Fire FC
# 1                   12900.00      12900.0   Meio-campo         Chicago Fire FC
# 2                   48712.50      41212.5       Ataque         Chicago Fire FC
# 3                 2666778.00    2492316.0       Ataque         Chicago Fire FC
# 4                  106391.00     106391.0       Defesa         Chicago Fire FC
# ..                       ...          ...          ...                     ...
# 611                 80000.00      80000.0       Defesa  Vancouver Whitecaps FC
# 612                368125.00     350000.0       Defesa  Vancouver Whitecaps FC
# 613                184000.00     175000.0       Defesa  Vancouver Whitecaps FC
# 614                 54075.00      54075.0       Ataque              Free Agent
# 615                453333.33     420000.0       Defesa              Free Agent
#
# [5553 rows x 8 columns]

# %%
# Excluir os clubes como "Free Agent" na base
df.drop(df[df['club'] == 'Free Agent'].index, inplace=True)

# %%
# Remover as colunas 'club' e 'position' e substituindo pelas 'new_position' e 'club_new'
df = df.drop(['club', 'position'], axis = 1)

# %%
# Nova Ordenação das colunas do dataframe
df = df[['Season', 'club_new', 'Name', 'new_position', 'guaranteed_compensation', 'base_salary']]
df.head()
# Out:
#    Season         club_new               Name new_position  \
# 0    2007  Chicago Fire FC        Chris Armas   Meio-campo
# 1    2007  Chicago Fire FC     Michael Banner   Meio-campo
# 2    2007  Chicago Fire FC       Chad Barrett       Ataque
# 3    2007  Chicago Fire FC  Cuauhtemoc Blanco       Ataque
# 4    2007  Chicago Fire FC         C.J. Brown       Defesa
#
#    guaranteed_compensation  base_salary
# 0                 225000.0     225000.0
# 1                  12900.0      12900.0
# 2                  48712.5      41212.5
# 3                2666778.0    2492316.0
# 4                 106391.0     106391.0

# %%
# Excluir registro quando o o salário é nulo
df = df[pd.notnull(df['base_salary'])]

# %%
# Observando o novo dataframe
df.count()
# Out:
# Season                     5127
# club_new                   5127
# Name                       5127
# new_position               5127
# guaranteed_compensation    5127
# base_salary                5127
# dtype: int64

# %% [markdown]
# ## Análise Univariada

# %%
# Criar o histograma da variável 'base_salary'
fig = px.histogram(df, x='base_salary',marginal = 'box', title='Distribuição dos salários base dos jogadores', histnorm='percent', opacity=0.7)

# Adicionar título aos eixos
fig.update_xaxes(title_text='Salário Base')
fig.update_yaxes(title_text='Qtd jogadores')

# Calcular a média e a mediana
media_salario = df['base_salary'].mean()
mediana_salario = df['base_salary'].median()

# Adicionar linhas para representar a média e a mediana
fig.add_vline(x=media_salario, line_color='red', annotation_text=f'Média: {media_salario:.2f}', annotation_position='top left', annotation_font_color='green')
fig.add_vline(x=mediana_salario, line_color='green', annotation_text=f'Mediana: {mediana_salario:.2f}', annotation_position='top right', annotation_font_color='red')

# Exibir o histograma
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="555eff8c-c97d-477c-9c4a-978d17916195" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("555eff8c-c97d-477c-9c4a-978d17916195")) {                    Plotly.newPlot(                        "555eff8c-c97d-477c-9c4a-978d17916195",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"percent","hovertemplate":"base_salary=%{x}\u003cbr\u003epercent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.7,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[225000.0,12900.0,41212.5,2492316.0,106391.0,58008.0,38000.0,44100.0,12900.0,120750.0,17700.0,160000.0,126500.0,130000.0,12900.0,12900.0,69300.0,32340.0,30000.0,42500.0,70000.0,48300.0,45000.0,36000.0,240000.0,12900.0,33000.0,57500.0,12900.0,12900.0,52491.6,30000.0,12900.0,72500.0,52237.5,17700.0,45000.0,70000.0,84000.0,17700.0,100000.0,90000.0,60000.0,12900.0,89250.0,100000.0,70000.0,245000.0,12900.0,12900.0,146991.6,70000.0,30000.0,67500.0,17700.0,41250.0,30000.0,165000.0,156000.0,45050.25,17700.0,150000.0,76650.0,30870.0,12900.0,12900.0,33000.0,100000.0,70008.0,120000.0,17700.0,46331.25,72000.0,12900.0,63000.0,50000.0,150000.0,43135.31,84000.0,60000.0,38456.25,33000.0,70000.0,156000.0,180000.0,17700.0,45000.0,147500.0,30000.0,30000.0,115000.0,30000.0,49350.0,17700.0,130000.0,12900.0,55000.0,17700.0,12900.0,200000.0,12900.0,280000.0,138000.0,70000.0,126000.0,76403.0,60000.0,57600.0,17700.0,12900.0,32819.0,12900.0,17700.0,80000.0,12900.0,872736.0,12900.0,100000.0,12900.0,48378.75,220800.0,50000.0,12900.0,33000.0,80000.0,30000.0,30000.0,17700.0,60000.0,325000.0,110000.0,67008.0,108000.0,30000.0,100008.0,33000.0,45000.0,30870.0,36000.0,45000.0,30870.0,30000.0,190008.0,12900.0,12900.0,12900.0,17700.0,265000.0,216000.0,72500.0,30000.0,30000.0,30000.0,17700.0,250000.0,12900.0,85000.0,36000.0,12900.0,155000.0,85000.0,52500.0,216667.0,30870.0,141750.0,17700.0,220000.0,195000.0,51149.0,96000.0,120000.0,324999.96,12900.0,12900.0,17700.0,31500.0,70000.0,12900.0,112500.0,17700.0,125000.0,51148.13,168000.0,110000.0,85000.0,50400.0,30000.0,100000.0,100000.0,42000.0,194750.0,17700.0,131250.0,17700.0,12900.0,36000.0,150000.0,30000.0,50000.0,33075.0,750000.0,12900.0,12900.0,30000.0,12900.0,165000.0,30000.0,30000.0,35750.0,44825.0,30000.0,33075.0,137500.0,30000.0,17700.0,154000.0,142500.0,5500000.08,192000.0,12900.0,900000.0,12900.0,50000.0,30870.0,85000.0,30000.0,40800.0,108000.0,95000.0,75000.0,52500.0,132000.0,17700.0,30000.0,45000.0,17700.0,131250.0,17700.0,156000.0,30000.0,17700.0,30870.0,12900.0,90000.0,12900.0,110000.0,12900.0,45000.0,63000.0,170625.0,12900.0,30000.0,47500.0,225000.0,12900.0,80575.0,150000.0,150000.0,30870.0,35500.0,44100.0,17700.0,30000.0,325008.0,50000.0,85000.0,1500000.0,12900.0,12900.0,12900.0,65000.0,48000.0,50600.0,30870.0,17700.0,12900.0,190000.0,12900.0,43200.0,56206.25,62606.25,47250.0,12900.0,100000.0,1000008.0,30000.0,175000.0,30870.0,17700.0,180000.0,17700.0,200000.0,65625.0,120000.0,75000.0,17700.0,70000.0,12900.0,30000.0,155000.0,72000.0,30000.0,30000.0,17700.0,33075.0,30000.0,12900.0,69300.0,48000.0,120000.0,265000.0,17700.0,64125.0,55000.0,41081.25,70000.0,45100.0,70008.0,54993.75,12900.0,30000.0,67200.0,150000.0,36000.0,220000.0,17700.0,99750.0,50000.0,12900.0,17700.0,30000.0,12900.0,142000.0,12900.0,17700.0,240000.0,90000.0,300000.0,90000.0,30000.0,125000.0,195000.0,47500.0,12900.0,12900.0,160000.0,12900.0,12900.0,166250.0,1500000.0,12900.0,105000.0,33000.0,12900.0,45000.0,17700.0,138000.0,75000.0,12900.0,53773.13,148838.0,143000.0,5500000.08,55000.0,2492316.0,12900.0,120000.0,17700.0,77500.0,33000.0,33000.0,45000.0,41250.0,12900.0,175000.0, ...

# %%
# Removendo entradas duplicadas
df_unique = df.drop_duplicates(subset=['Name'])

# Filtrando os top 10 nomes com maiores salários e ordenando do maior para o menor
top_10_salaries = df_unique.nlargest(10, 'base_salary').sort_values('base_salary', ascending=True)

# Criando o gráfico de barras horizontais
fig = px.bar(top_10_salaries,
             y='Name',  # Nome dos jogadores no eixo y
             x='base_salary',  # Salário no eixo x
             orientation='h',  # Orientação horizontal
             title='Top 10 jogadores com Maiores Salários',
             labels={'base_salary': 'Salário Base', 'Name': 'Nome do Jogador'})

# Exibindo o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b949ce5b-1344-4470-ad84-954f314872c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b949ce5b-1344-4470-ad84-954f314872c3")) {                    Plotly.newPlot(                        "b949ce5b-1344-4470-ad84-954f314872c3",                        [{"alignmentgroup":"True","hovertemplate":"Sal\u00e1rio Base=%{x}\u003cbr\u003eNome do Jogador=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[5000000.04,5400000.0,5500000.08,5544000.0,5600000.0,6000000.0,6000000.0,6000000.0,6200004.0,6660000.0],"xaxis":"x","y":["Thierry Henry","Bastian Schweinsteiger","David Beckham","Rafael Marquez","Sebastian Giovinco","Michael Bradley","Jermain Defoe","Frank Lampard","Steven Gerrard","Kaka"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a ...

# %%
# Análise do salário médio por clube
salaries_stats = df.groupby('club_new')['base_salary'].agg(['mean']).reset_index()

# Criar o gráfico de barras
fig = px.bar(salaries_stats,
             x='mean',  # Inverter eixo x e y para um gráfico de barras horizontais
             y='club_new',
             barmode='group',
             labels={'club_new': 'Clube', 'mean': 'Salário Médio'},
             title='Média Salarial por Clube')

# Rótulo dos dados do gráfico e propriedades do eixo y
fig.update_traces(
    texttemplate='%{x}',
    textposition='outside',   # Posiciona o rótulo acima da barra
    hoverinfo='skip'          # Remove informações ao passar o mouse
)

# Exibindo o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3cbf01bb-80e2-43dd-a055-cb99356174a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3cbf01bb-80e2-43dd-a055-cb99356174a1")) {                    Plotly.newPlot(                        "3cbf01bb-80e2-43dd-a055-cb99356174a1",                        [{"alignmentgroup":"True","hovertemplate":"Sal\u00e1rio M\u00e9dio=%{x}\u003cbr\u003eClube=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"outside","x":[223020.0,184690.81463157895,88933.57348416289,128405.30215488216,122097.91395904437,124536.9121724138,123293.79816666667,130132.90689781023,408565.9727972028,59004.0,186194.23230769232,171726.95444444445,138652.42474820142,614501.33575,292814.9372887324,371847.33483146067,146042.271959799,181936.57312169313,130632.96078014183,129221.787890625,178225.5720247934,135825.3150522648,340349.4052727273,157899.49135678392],"xaxis":"x","y":["Atlanta United FC","Chicago Fire FC","Chivas USA","Colorado Rapids","Columbus Crew SC","D.C. United","FC Dallas","Houston Dynamo FC","LA Galaxy","Los Angeles Football Club","Minnesota United FC","Montreal Impact","New England Revolution","New York City FC","New York Red Bulls","Orlando City SC","Philadelphia Union","Portland Timbers","Real Salt Lake","San Jose Earthquakes","Seattle Sounders FC","Sporting Kansas City","Toronto FC","Vancouver Whitecaps FC"],"yaxis":"y","type":"bar","hoverinfo":"skip","texttemplate":"%{x}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d088 ...

# %%
# Análise do salário médio por posição do jogador
salaries_stats = df.groupby('new_position')['base_salary'].agg(['mean']).reset_index()

# Criar o gráfico de barras
fig = px.bar(salaries_stats,
             x='new_position',
             y='mean',
             barmode='group',
             labels={'new_position': 'Posição', 'mean': 'Salário Médio'},
             title='Média Salarial por Posição')

# Rótulo dos dados do gráfico e propriedades do eixo y
fig.update_traces(
    texttemplate='%{y}',
    textposition='outside',   # Posiciona o rótulo acima da barra
    hoverinfo='skip'          # Remove informações ao passar o mouse
)

# Exibindo o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9fc658f8-4602-4614-85c3-21b3057f1fbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fc658f8-4602-4614-85c3-21b3057f1fbb")) {                    Plotly.newPlot(                        "9fc658f8-4602-4614-85c3-21b3057f1fbb",                        [{"alignmentgroup":"True","hovertemplate":"Posi\u00e7\u00e3o=%{x}\u003cbr\u003eSal\u00e1rio M\u00e9dio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["Ataque","Defesa","Meio-campo","Outro"],"xaxis":"x","y":[267111.6568391867,116637.15380786461,213155.5716033547,61912.50444444445],"yaxis":"y","type":"bar","hoverinfo":"skip","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode" ...

# %%
# Distrubuição de jogadores analisados por posição
fig = px.histogram(df, x='new_position', color='new_position')

# Rótulo dos dados do gráfico e propriedades do eixo y
fig.update_traces(
    texttemplate='%{y}',
    textposition='auto',
    hoverinfo='skip'  # Remove informações ao passar o mouse
)

# Propriedades do eixo X e título do eixo X
fig.update_xaxes(
    title_text='Posição',
    categoryorder='total descending'  # Ordenação decrescente
)

# Propriedades do título principal do gráfico
fig.update_layout(
    title_text='Quantidade de jogadores analisados por posição',
    yaxis_visible=False,  # Eixo y invisível
    yaxis_showticklabels=False,  # Marcas de escala invisíveis no eixo y
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2ec37742-14e4-4646-9711-9d8f9c883181" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ec37742-14e4-4646-9711-9d8f9c883181")) {                    Plotly.newPlot(                        "2ec37742-14e4-4646-9711-9d8f9c883181",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"new_position=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Meio-campo","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Meio-campo","offsetgroup":"Meio-campo","orientation":"v","showlegend":true,"x":["Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-cam ...

# %%
# Distrubuição de jogadores analisados por clube
fig = px.histogram(df, y='club_new', color='club_new', color_discrete_sequence=['skyblue'])

# Rótulo dos dados do gráfico e propriedades do eixo x
fig.update_traces(
    texttemplate='%{x}',
    textposition='auto',
    hoverinfo='skip',  # Remove informações ao passar o mouse
)

# Propriedades do eixo y e título do eixo y
fig.update_yaxes(
    title_text='Clube',
    categoryorder='total ascending'  # Ordenação decrescente
)

# Propriedades do título principal do gráfico
fig.update_layout(
    title_text='Quantidade de jogadores analisados por clube',
    xaxis_visible=False,  # Eixo x invisível
    xaxis_showticklabels=False,  # Marcas de escala invisíveis no eixo x
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5fffbf9d-dee8-47bd-9f54-5ecf7ed7e052" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fffbf9d-dee8-47bd-9f54-5ecf7ed7e052")) {                    Plotly.newPlot(                        "5fffbf9d-dee8-47bd-9f54-5ecf7ed7e052",                        [{"alignmentgroup":"True","bingroup":"y","hovertemplate":"club_new=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chicago Fire FC","marker":{"color":"skyblue","pattern":{"shape":""}},"name":"Chicago Fire FC","offsetgroup":"Chicago Fire FC","orientation":"h","showlegend":true,"xaxis":"x","y":["Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago F ...

# %%
# Distrubuição de jogadores analisados por temporada
fig = px.histogram(df, x='Season', color='Season')

# Rótulo dos dados do gráfico
fig.update_traces(texttemplate='%{y}', textposition='auto')

# Propriedades do eixo y: Eixo y invisível e marca de escala invisível também
fig.update_yaxes(visible=False, showticklabels=False)

# Propriedades do título do eixo X do gráfico e ajuste da orientação dos rótulos
fig.update_xaxes(title_text='Temporada', tickangle=45, tickfont=dict(size=10))

# Propriedades do título principal do gráfico
fig.update_layout(title_text='Quantidade de jogadores analisados por temporada')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4f265220-e32f-4990-a715-58db7b098e22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f265220-e32f-4990-a715-58db7b098e22")) {                    Plotly.newPlot(                        "4f265220-e32f-4990-a715-58db7b098e22",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Season=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2007","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2007","offsetgroup":"2007","orientation":"v","showlegend":true,"x":[2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007],"xaxis":"x","yaxis":"y","type":"histogram","textposition":"auto","texttemplate":"%{y}"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Season=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2008","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2008","offsetgroup":"2008","orientation":"v","showlegend":true,"x":[2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2 ...

# %% [markdown]
# ## Análise Bivariada

# %%
# Exclusão dos salários acima de 2M
df = df.query('base_salary < 2000000')

# %%
# Distribuição salarial ao longo dos anos
fig = px.box(df, x='Season', y='base_salary', title='Distribuição de Salários ao longo dos Anos',color='Season',color_discrete_sequence=px.colors.qualitative.G10)
fig.update_yaxes(title_text='Base Salário em USD')
fig.update_xaxes(title_text='Temporada')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ffea1283-363d-49a7-add0-28c49c9e6de2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffea1283-363d-49a7-add0-28c49c9e6de2")) {                    Plotly.newPlot(                        "ffea1283-363d-49a7-add0-28c49c9e6de2",                        [{"alignmentgroup":"True","hovertemplate":"Season=%{x}\u003cbr\u003ebase_salary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2007","marker":{"color":"#3366CC"},"name":"2007","notched":false,"offsetgroup":"2007","orientation":"v","showlegend":true,"x":[2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007],"x0":" ","xaxis":"x","y":[225000.0,12900.0,41212.5,106391.0,58008.0,38000.0,44100.0,12900.0,120750.0,17700.0,160000.0,126500.0,130000.0,12900.0,12900.0,69300.0,32340.0,30000.0,42500.0,70000.0,48300.0,45000.0,36000.0,240000.0,12900.0,33000.0,57500.0,12900.0,12900.0,52491.6,30000.0,12900.0,72500.0,52237.5,17700.0,45000.0,70000.0,84000.0,17700.0,100000.0,90000.0,60000.0,12900.0,89250.0,100000.0,70000.0,245000.0,12900.0,12900.0,146991.6,70000.0,30000.0,67500.0,17700.0,41250.0,30000.0,165000.0,156000.0,45050.25,17700.0,150000.0,76650.0,30870.0,12900.0,12900.0,33000.0,100000.0,70008.0,120000.0,17700.0,46331.25,72000.0,12900.0,63000.0,50000.0,150000.0,43135.31,84000.0,60000.0,38456.25,33000.0,70000.0,156000.0,180000.0,17700.0,45000.0,147500.0,30000.0,30000.0,115000.0,30000.0,49350.0,17700.0,130000.0,12900.0,55000.0,17700.0,12900.0,200000.0,12900.0,280000.0,138000.0,70000.0,126000.0,76403.0,60000.0,57600.0,17700.0,12900.0,32819.0,12900.0,17700.0,80000.0,12900.0,872736.0,12900.0,100000.0,12900.0,48378.75,220800.0,50000.0,12900.0,33000.0,80000.0,30000.0,30000.0,17700.0,60000.0,325000.0,110000.0,67008.0,108000.0,30000.0,100008.0,33000.0,45000.0,30870.0,36000.0,45000.0,30870.0,30000.0,190008.0,12900.0,12900.0,12900.0,17700.0,265000.0,216000.0,72500.0,30000.0,30000.0,30000.0,17700.0,250000.0,12900.0,85000.0,36000.0,12900.0,155000.0,85000.0,52500.0,216667.0,30870.0,141750.0,17700.0,220000.0,195000.0,51149.0,96000.0,120000.0,324999.96,12900.0,12900.0,177 ...

# %%
# Tamanho da empresa impacta no valor salarial?

fig = px.box(df, x='club_new', y='base_salary',
             title='Impacto do time na base salarial dos jogadores',
             labels={'club': 'Time', 'base_salary': 'Base Salário (em USD)'},
             color='club_new',color_discrete_sequence=px.colors.qualitative.G10)  # Isso vai colorir as caixas com base no tamanho da empresa
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c2efdcb2-f4e5-4080-9d67-8e9361d9d91f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2efdcb2-f4e5-4080-9d67-8e9361d9d91f")) {                    Plotly.newPlot(                        "c2efdcb2-f4e5-4080-9d67-8e9361d9d91f",                        [{"alignmentgroup":"True","hovertemplate":"club_new=%{x}\u003cbr\u003eBase Sal\u00e1rio (em USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chicago Fire FC","marker":{"color":"#3366CC"},"name":"Chicago Fire FC","notched":false,"offsetgroup":"Chicago Fire FC","orientation":"v","showlegend":true,"x":["Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chicago Fire FC","Chic ...

# %%
# Relação do nível experiência com o salário dos funcionários
fig = px.box(df, x='new_position', y='base_salary',
             title='Relação da posição nos Salários dos jogadores',
             labels={'new_position': 'Posição do jogador', 'base_salary': 'Salário (em USD)'},
             color='new_position',color_discrete_sequence=px.colors.qualitative.G10)  # Isso vai colorir as caixas com base no tamanho da empresa
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6d1220bd-15c1-43b3-b642-888542eb8314" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d1220bd-15c1-43b3-b642-888542eb8314")) {                    Plotly.newPlot(                        "6d1220bd-15c1-43b3-b642-888542eb8314",                        [{"alignmentgroup":"True","hovertemplate":"Posi\u00e7\u00e3o do jogador=%{x}\u003cbr\u003eSal\u00e1rio (em USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Meio-campo","marker":{"color":"#3366CC"},"name":"Meio-campo","notched":false,"offsetgroup":"Meio-campo","orientation":"v","showlegend":true,"x":["Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo","Meio-campo" ...
